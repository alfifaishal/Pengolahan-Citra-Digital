# %% [markdown]
# ### **Muhammad Alfi Faishal - 2106022 - UTS GENAP A**

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

from google.colab.patches import cv2_imshow
from skimage import io
from PIL import Image

from google.colab import drive
drive.mount('/content/drive')

#Libraries yang digunakan untuk pemrosesan citra.
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#link image
url = "/content/drive/MyDrive/Foto/sayaa.jpg"


image = io.imread(url)
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
final_frame = cv.hconcat((image, image_2))
cv2_imshow(final_frame)

#memuat gambar dari URL, mengonversi mode warna gambar,
#dan menampilkannya dalam format yang sesuai untuk visualisasi di lingkungan Google Colab.
# Out:
# <PIL.Image.Image image mode=RGB size=450x225>

# %%
print(image.size) #Ukuran total gambar
print(image.shape) #Bentuk (shape) gambar
print(image.dtype) #Tipe data gambar
# Out:
# 151875
# (225, 225, 3)
# uint8

# %%
import numpy as np
a = np.array([[1,2,2,2,10],[10,20,30,40,50]]) #membuat array
print(a)
print(a.ravel())
print(a.flatten())
plt.hist(a.ravel(),bins = 50, range = [0,50])
plt.show()
#menampilkan hasil histogram
# Out:
# [[ 1  2  2  2 10]
#  [10 20 30 40 50]]
# [ 1  2  2  2 10 10 20 30 40 50]
# [ 1  2  2  2 10 10 20 30 40 50]

# %%
plt.hist(image.ravel(), bins = 256, range = [0,256])
plt.show()

#membuat histogram dari piksel intensitas gambar yang telah di-ravel (mengubah array menjadi 1d)

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv.calcHist([image], [i], None, [256], [0,256])
  plt.plot(histogr, color = col)
  plt.xlim([0,325])
plt.show()

#menghitung dan menampilkan histogram warna

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv.calcHist([image], [i], None, [4], [0,256])
  plt.plot(histogr, color = col)
  plt.xlim([0,4])
plt.show()

#prbedaan jumlah bin, dan tampilan untuk x di histogram

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv.calcHist([image], [i], None, [8], [0,256]) #jumlah bin beda
  plt.plot(histogr, color = col)
  plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv.calcHist([image], [i], None, [16], [0,256])
  plt.plot(histogr, color = col)
plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv.calcHist([image], [i], None, [32], [0,256])
  plt.plot(histogr, color = col)
plt.show()

# %%
b,g,r = cv.split(image)
cv2_imshow(b)
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %%
image = io.imread(url)

#blue channel
bluech = image[:,:,0]
cv2_imshow(bluech)
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %%
plt.hist(bluech.ravel(), 16, [0, 256], color='blue')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 8, [0, 256], color='blue')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 32, [0, 256], color='blue')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 256, [0, 256], color='blue')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 4, [0, 256], color='blue')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
plt.show()

# %%
#green channel
greench = image[:,:,1]
cv2_imshow(greench)
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %%
plt.hist(bluech.ravel(), 8, [0, 256], color='green')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 4, [0, 256], color='green')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 16, [0, 256], color='green')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 32, [0, 256], color='green')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 256, [0, 256], color='green')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %%
#red channel

redch = image[:,:,2]
cv2_imshow(redch)
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %%
plt.hist(redch.ravel(), 256, [0, 256], color='red')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(redch.ravel(), 32, [0, 256], color='red')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(redch.ravel(), 16, [0, 256], color='red')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
# Out:
# Text(0, 0.5, 'Num of Pixel')

# %%
plt.hist(redch.ravel(), 8, [0, 256], color='red')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
# Out:
# Text(0, 0.5, 'Num of Pixel')

# %%
plt.hist(redch.ravel(), 4, [0, 256], color='red')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
# Out:
# Text(0, 0.5, 'Num of Pixel')

# %%
gray_image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
cv2_imshow(gray_image)

#konversi dari rgb ke grayscale
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %%
plt.hist(gray_image.ravel(), bins = 256, range = [0,256])
plt.show()


print(gray_image.size)
print(gray_image.shape)
print(gray_image.dtype)
# Out:
# 50625
# (225, 225)
# uint8

# %%
plt.hist(gray_image.ravel(), bins = 4, range = [0,256])
plt.show()


print(gray_image.size)
print(gray_image.shape)
print(gray_image.dtype)
# Out:
# 50625
# (225, 225)
# uint8

# %%
invert_gray = 255 - gray_image
cv2_imshow(invert_gray)

#menambahkan effect atau membuat gambar menjadi negatif(invert)
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %%
plt.hist(invert_gray.ravel(), bins = 256, range = [0,256])
plt.show()

# %%
bright_image = (100.0/255)*gray_image + 100
cv2_imshow(bright_image)
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %%
plt.hist(bright_image.ravel(), bins = 256, range = [0,256])
plt.show()

# %%
darken_image = 255.0*(gray_image/255.0)**2
cv2_imshow(darken_image)
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %%
plt.hist(darken_image.ravel(), bins = 256, range = [0,256])
plt.show()
